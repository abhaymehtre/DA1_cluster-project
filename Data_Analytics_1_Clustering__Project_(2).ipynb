# %% [markdown]
# <a href="https://colab.research.google.com/github/abhaymehtre/DA1_cluster-project/blob/main/Data_Analytics_1_Clustering__Project_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt; plt.rcdefaults()

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

#Displaying the complete columns and Rows in the data set.
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# Imputing the Nan values
from sklearn.impute import SimpleImputer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path of the CSV File

path = '/content/drive/MyDrive/DA1 Dataset/football_data.csv'

#Reading the CSV File

football_df = pd.read_csv(path)

football_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo    Value  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png     €77M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png     €72M
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png    €102M
#
#     Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  €565K     2202           Left                       5.0        4.0
# 1  €405K     2228          Right                       5.0        4.0
# 2  €290K     2143          Right                       5.0        5.0
# 3  €260K     1471          Right                       4.0        3.0
# 4  €355K     2281          Right                       4.0        5.0
#
#    Skill Moves       Work Rate   Body Type Real Face Position  Jersey Number  \
# 0          4.0  Medium/ Medium       Messi       Yes       RF           10.0
# 1          5.0       High/ Low  C. Ronaldo       Yes       ST            7.0
# 2          5.0    High/ Medium      Neymar       Yes       LW           10.0
# 3          1.0  Medium/ Medium        Lean       Yes       GK            1.0
# 4          4.0      High/ High      Normal       Yes      RCM            7.0
#
#          Joined Loaned From Contract Valid Until Height  Weight    LS    ST  \
# 0   Jul 1, 2004         NaN                 2021    5'7  159lbs  88+2  88+2
# 1  Jul 10, 2018         NaN                 2022    6'2  183lbs  91+3  91+3
# 2   Aug 3, 2017         NaN                 2022    5'9  150lbs  84+3  84+3
# 3   Jul 1, 2011         NaN                 2020    6'4  168lbs   NaN   NaN
# 4  Aug 30, 2015         NaN                 2023   5'11  154lbs  82+3  82+3
#
#      RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 0  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2  93+2  91+2  84+2  84+2
# 1  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3
# 2  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  88+3  81+3  81+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3
#
#     RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 0  84+2  91+2  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2  59+2
# 1  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  81+3  88+3  65+3  60+3  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0      84.0       95.0             70.0          90.0     86.0       97.0
# 1      84.0       94.0             89.0          81.0     87.0       88.0
# 2      79.0       87.0             62.0          84.0     84.0       96.0
# 3      17.0       13.0             21.0          50.0     13.0       18.0
# 4      93.0       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 0   93.0        94.0         87.0         96.0          91.0         86.0
# 1   81.0        76.0         77.0         94.0          89.0         91.0
# 2   88.0        87.0         78.0         95.0          94.0         90.0
# 3   21.0        19.0         51.0         42.0          57.0         58.0
# 4   85.0        83.0         91.0         91.0          78.0         76.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0     91.0       95.0     95.0       85.0     68.0     72.0      59.0
# 1     87.0       96.0     70.0       95.0     95.0     88.0      79.0
# 2     96.0       94.0     84.0       80.0     61.0     81.0      49.0
# 3     60.0       90.0     43.0       31.0     67.0     43.0      64.0
# 4     79.0       91.0     77.0       91.0     63.0     90.0      75.0
#
#    LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0       94.0        48.0           22.0         94.0    94.0       75.0
# 1       93.0        63.0           29.0         95.0    82.0       85.0
# 2       82.0        56.0           36.0         89.0    87.0       81.0
# 3       12.0        38.0           30.0         12.0    68.0       40.0
# 4       91.0        76.0           61.0         87.0    94.0       79.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0       96.0     33.0            28.0           26.0       6.0        11.0
# 1       95.0     28.0            31.0           23.0       7.0        11.0
# 2       94.0     27.0            24.0           33.0       9.0         9.0
# 3       68.0     15.0            21.0           13.0      90.0        85.0
# 4       88.0     68.0            58.0           51.0      15.0        13.0
#
#    GKKicking  GKPositioning  GKReflexes Release Clause
# 0       15.0           14.0         8.0        €226.5M
# 1       15.0           14.0        11.0        €127.1M
# 2       15.0           15.0        11.0        €228.1M
# 3       87.0           88.0        94.0        €138.6M
# 4        5.0           10.0        13.0        €196.4M

# %%
# Converting  the columns to string for striping the unwanted data.


a = ['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB']


for i in a :

  # Converting the column data to string
  football_df[i] = football_df[i].astype(str)

  #Imputation on numeric values
  football_df[i].fillna("0", inplace = True)


  #Striping the data that is present after "+"
  football_df[i] = football_df[i].map(lambda x: x.split("+", 1)[0].rstrip())

# %%
# Imputing the Numeric values

football_df['ShortPassing'].fillna(football_df['ShortPassing'].mean(), inplace = True)
football_df['Volleys'].fillna(football_df['Volleys'].mean(), inplace = True)
football_df['Dribbling'].fillna(football_df['Dribbling'].mean(), inplace = True)
football_df['Curve'].fillna(football_df['Curve'].mean(), inplace = True)
football_df['FKAccuracy'].fillna(football_df['FKAccuracy'], inplace = True)
football_df['LongPassing'].fillna(football_df['LongPassing'].mean(), inplace = True)
football_df['BallControl'].fillna(football_df['BallControl'].mean(), inplace = True)
football_df['HeadingAccuracy'].fillna(football_df['HeadingAccuracy'].mean(), inplace = True)
football_df['Finishing'].fillna(football_df['Finishing'].mean(), inplace = True)
football_df['Crossing'].fillna(football_df['Crossing'].mean(), inplace = True)
football_df['Weight'].fillna('200lbs', inplace = True)
football_df['Contract Valid Until'].fillna(2019, inplace = True)
football_df['Height'].fillna("5'11", inplace = True)
football_df['Joined'].fillna('Jul 1, 2018', inplace = True)
football_df['Body Type'].fillna('Normal', inplace = True)
football_df['Position'].fillna('ST', inplace = True)
football_df['Club'].fillna('No Club', inplace = True)
football_df['Work Rate'].fillna('Medium/ Medium', inplace = True)
football_df['Skill Moves'].fillna(football_df['Skill Moves'].median(), inplace = True)
football_df['Weak Foot'].fillna(3, inplace = True)
football_df['Preferred Foot'].fillna('Right', inplace = True)
football_df['International Reputation'].fillna(1, inplace = True)
football_df['Wage'].fillna('€200K', inplace = True)
football_df['Release Clause'].fillna('€196.4M', inplace = True)

football_df.fillna(0, inplace = True)

football_df.isnull().sum()
# Out:
# Unnamed: 0                  0
# ID                          0
# Name                        0
# Age                         0
# Photo                       0
# Nationality                 0
# Flag                        0
# Overall                     0
# Potential                   0
# Club                        0
# Club Logo                   0
# Value                       0
# Wage                        0
# Special                     0
# Preferred Foot              0
# International Reputation    0
# Weak Foot                   0
# Skill Moves                 0
# Work Rate                   0
# Body Type                   0
# Real Face                   0
# Position                    0
# Jersey Number               0
# Joined                      0
# Loaned From                 0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# LS                          0
# ST                          0
# RS                          0
# LW                          0
# LF                          0
# CF                          0
# RF                          0
# RW                          0
# LAM                         0
# CAM                         0
# RAM                         0
# LM                          0
# LCM                         0
# CM                          0
# RCM                         0
# RM                          0
# LWB                         0
# LDM                         0
# CDM                         0
# RDM                         0
# RWB                         0
# LB                          0
# LCB                         0
# CB                          0
# RCB                         0
# RB                          0
# Crossing                    0
# Finishing                   0
# HeadingAccuracy             0
# ShortPassing                0
# Volleys                     0
# Dribbling                   0
# Curve                       0
# FKAccuracy                  0
# LongPassing                 0
# BallControl                 0
# Acceleration                0
# SprintSpeed                 0
# Agility                     0
# Reactions                   0
# Balance                     0
# ShotPower                   0
# Jumping                     0
# Stamina                     0
# Strength                    0
# LongShots                   0
# Aggression                  0
# Interceptions               0
# Positioning                 0
# Vision                      0
# Penalties                   0
# Composure                   0
# Marking                     0
# StandingTackle              0
# SlidingTackle               0
# GKDiving                    0
# GKHandling                  0
# GKKicking                   0
# GKPositioning               0
# GKReflexes                  0
# Release Clause              0
# dtype: int64

# %%
# Extracting the Year from the given date format for column: 'Joined'

def parse_date(s):
    if isinstance(s, str) and ',' in s:
        return float(s.split()[2])
    else:
        return int(s)
        
football_df['Joined'] = football_df['Joined'].apply(parse_date)
football_df['Contract Valid Until'] = football_df['Contract Valid Until'].apply(parse_date)

# %%
# converting the Body Types

football_df.loc[~football_df['Body Type'].isin(['Normal', 'Stocky', 'Lean']), 'Body Type'] = football_df['Body Type'].value_counts().index[0]
football_df['Body Type'].value_counts()
# Out:
# Normal    10650
# Lean       6417
# Stocky     1140
# Name: Body Type, dtype: int64

# %%
# football_df.isnull().sum()

# %%
# Converting the height format 

football_df.replace({"Height": {"'" : "."}}, regex=True, inplace=True)

# Converting the Weight format 

football_df.replace({"Weight": {"lbs" : ""}}, regex=True, inplace=True)

# %%
# Converting the columns of data frame to numeric

objtofloat = ['Height','Weight','LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM',	'RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB']

for a in objtofloat:
    football_df[a] = football_df[a].astype(float, errors = 'raise')

# %%
# Data Cleaned completely

def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

football_df['Value'] = football_df['Value'].apply(lambda x: extract_value_from(x))
football_df['Wage'] = football_df['Wage'].apply(lambda x: extract_value_from(x))   
football_df['Release Clause'] = football_df['Release Clause'].apply(lambda x: extract_value_from(x))

# %%
football_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
#
#          Value      Wage  Special Preferred Foot  International Reputation  \
# 0  110500000.0  565000.0     2202           Left                       5.0
# 1   77000000.0  405000.0     2228          Right                       5.0
# 2  118500000.0  290000.0     2143          Right                       5.0
# 3   72000000.0  260000.0     1471          Right                       4.0
# 4  102000000.0  355000.0     2281          Right                       4.0
#
#    Weak Foot  Skill Moves       Work Rate Body Type Real Face Position  \
# 0        4.0          4.0  Medium/ Medium    Normal       Yes       RF
# 1        4.0          5.0       High/ Low    Normal       Yes       ST
# 2        5.0          5.0    High/ Medium    Normal       Yes       LW
# 3        3.0          1.0  Medium/ Medium      Lean       Yes       GK
# 4        5.0          4.0      High/ High    Normal       Yes      RCM
#
#    Jersey Number  Joined Loaned From  Contract Valid Until  Height  Weight  \
# 0           10.0  2004.0           0                2021.0    5.70   159.0
# 1            7.0  2018.0           0                2022.0    6.20   183.0
# 2           10.0  2017.0           0                2022.0    5.90   150.0
# 3            1.0  2011.0           0                2020.0    6.40   168.0
# 4            7.0  2015.0           0                2023.0    5.11   154.0
#
#      LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM  \
# 0  88.0  88.0  88.0  92.0  93.0  93.0  93.0  92.0  93.0  93.0  93.0  91.0
# 1  91.0  91.0  91.0  89.0  90.0  90.0  90.0  89.0  88.0  88.0  88.0  88.0
# 2  84.0  84.0  84.0  89.0  89.0  89.0  89.0  89.0  89.0  89.0  89.0  88.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  82.0  82.0  82.0  87.0  87.0  87.0  87.0  87.0  88.0  88.0  88.0  88.0
#
#     LCM    CM   RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB  \
# 0  84.0  84.0  84.0  91.0  64.0  61.0  61.0  61.0  64.0  59.0  47.0  47.0
# 1  81.0  81.0  81.0  88.0  65.0  61.0  61.0  61.0  65.0  61.0  53.0  53.0
# 2  81.0  81.0  81.0  88.0  65.0  60.0  60.0  60.0  65.0  60.0  47.0  47.0
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  87.0  87.0  87.0  88.0  77.0  77.0  77.0  77.0  77.0  73.0  66.0  66.0
#
#     RCB    RB  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 0  47.0  59.0      84.0       95.0             70.0          90.0     86.0
# 1  53.0  61.0      84.0       94.0             89.0          81.0     87.0
# 2  47.0  60.0      79.0       87.0             62.0          84.0     84.0
# 3   NaN   NaN      17.0       13.0             21.0          50.0     13.0
# 4  66.0  73.0      93.0       82.0             55.0          92.0     82.0
#
#    Dribbling  Curve  FKAccuracy  LongPassing  BallControl  Acceleration  \
# 0       97.0   93.0        94.0         87.0         96.0          91.0
# 1       88.0   81.0        76.0         77.0         94.0          89.0
# 2       96.0   88.0        87.0         78.0         95.0          94.0
# 3       18.0   21.0        19.0         51.0         42.0          57.0
# 4       86.0   85.0        83.0         91.0         91.0          78.0
#
#    SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  \
# 0         86.0     91.0       95.0     95.0       85.0     68.0     72.0
# 1         91.0     87.0       96.0     70.0       95.0     95.0     88.0
# 2         90.0     96.0       94.0     84.0       80.0     61.0     81.0
# 3         58.0     60.0       90.0     43.0       31.0     67.0     43.0
# 4         76.0     79.0       91.0     77.0       91.0     63.0     90.0
#
#    Strength  LongShots  Aggression  Interceptions  Positioning  Vision  \
# 0      59.0       94.0        48.0           22.0         94.0    94.0
# 1      79.0       93.0        63.0           29.0         95.0    82.0
# 2      49.0       82.0        56.0           36.0         89.0    87.0
# 3      64.0       12.0        38.0           30.0         12.0    68.0
# 4      75.0       91.0        76.0           61.0         87.0    94.0
#
#    Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0       75.0       96.0     33.0            28.0           26.0       6.0
# 1       85.0       95.0     28.0            31.0           23.0       7.0
# 2       81.0       94.0     27.0            24.0           33.0       9.0
# 3       40.0       68.0     15.0            21.0           13.0      90.0
# 4       79.0       88.0     68.0            58.0           51.0      15.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause
# 0        11.0       15.0           14.0         8.0     226500000.0
# 1        11.0       15.0           14.0        11.0     127100000.0
# 2         9.0       15.0           15.0        11.0     228100000.0
# 3        85.0       87.0           88.0        94.0     138600000.0
# 4        13.0        5.0           10.0        13.0     196400000.0

# %%
# Creating a copy of data frame

Actual_football_df = football_df.copy()

# %%
correlated_features = set()
correlation_matrix = football_df.corr()


for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.9:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
print(len(correlated_features))

print(correlated_features)
# Out:
# 37
# {'Marking', 'CAM', 'Dribbling', 'ShortPassing', 'BallControl', 'GKHandling', 'RF', 'LF', 'RDM', 'CF', 'LCM', 'LDM', 'Overall', 'GKPositioning', 'RCB', 'GKKicking', 'ST', 'Interceptions', 'CDM', 'RCM', 'LB', 'LAM', 'RAM', 'RM', 'RB', 'CM', 'GKReflexes', 'LCB', 'RWB', 'SprintSpeed', 'SlidingTackle', 'StandingTackle', 'LW', 'RS', 'RW', 'LM', 'CB'}

# %%
# Dropping the columns that are not required.

# Column Names: 'ID', 'Name', 'Photo', 'Flag', 'Club Logo', 'Real Face', 'Jersey Number', 'Loaned From'

football_df.drop(['ID', 'Name', 'Photo', 'Flag', 'Club Logo', 'Real Face', 'Loaned From'], axis='columns', inplace=True)

# Below columns are highly corelated (more than 0.9). So dropping them.
football_df.drop(['LCB', 'CF', 'Overall', 'LAM', 'RAM', 'StandingTackle', 'LF', 'RF', 'LB', 'SlidingTackle', 'LCM', 'LM', 'RWB', 'RDM', 'ST', 'CAM', 'RM', 'SprintSpeed', 'BallControl', 'GKReflexes', 'CB', 'RB', 'ShortPassing', 'LDM', 'Marking', 'RS', 'GKKicking', 'RW', 'Interceptions', 'Dribbling', 'CDM', 'RCM', 'GKHandling', 'CM', 'GKPositioning', 'LW', 'RCB'], axis='columns', inplace=True)

# %%
football_df.isnull().sum()
# Out:
# Unnamed: 0                     0
# Age                            0
# Nationality                    0
# Potential                      0
# Club                           0
# Value                          0
# Wage                           0
# Special                        0
# Preferred Foot                 0
# International Reputation       0
# Weak Foot                      0
# Skill Moves                    0
# Work Rate                      0
# Body Type                      0
# Position                       0
# Jersey Number                  0
# Joined                         0
# Contract Valid Until           0
# Height                         0
# Weight                         0
# LS                          2085
# LWB                         2085
# Crossing                       0
# Finishing                      0
# HeadingAccuracy                0
# Volleys                        0
# Curve                          0
# FKAccuracy                     0
# LongPassing                    0
# Acceleration                   0
# Agility                        0
# Reactions                      0
# Balance                        0
# ShotPower                      0
# Jumping                        0
# Stamina                        0
# Strength                       0
# LongShots                      0
# Aggression                     0
# Positioning                    0
# Vision                         0
# Penalties                      0
# Composure                      0
# GKDiving                       0
# Release Clause                 0
# dtype: int64

# %%
# Splitting the Categorical and Numerical columns

numeric_data = football_df.select_dtypes(include=['int','float'])

categorical_data = football_df.select_dtypes(include=['object'])

# %%
# Imputing the NAN values present in the numeric_data 

c = numeric_data.columns

c= list(c)

for i in c:

  numeric_data[i] = numeric_data[i].replace(np.nan, 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
numeric_data.head()
# Out:
#    Unnamed: 0  Age  Potential        Value      Wage  Special  \
# 0           0   31         94  110500000.0  565000.0     2202
# 1           1   33         94   77000000.0  405000.0     2228
# 2           2   26         93  118500000.0  290000.0     2143
# 3           3   27         93   72000000.0  260000.0     1471
# 4           4   27         92  102000000.0  355000.0     2281
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  Joined  \
# 0                       5.0        4.0          4.0           10.0  2004.0
# 1                       5.0        4.0          5.0            7.0  2018.0
# 2                       5.0        5.0          5.0           10.0  2017.0
# 3                       4.0        3.0          1.0            1.0  2011.0
# 4                       4.0        5.0          4.0            7.0  2015.0
#
#    Contract Valid Until  Height  Weight    LS   LWB  Crossing  Finishing  \
# 0                2021.0    5.70   159.0  88.0  64.0      84.0       95.0
# 1                2022.0    6.20   183.0  91.0  65.0      84.0       94.0
# 2                2022.0    5.90   150.0  84.0  65.0      79.0       87.0
# 3                2020.0    6.40   168.0   0.0   0.0      17.0       13.0
# 4                2023.0    5.11   154.0  82.0  77.0      93.0       82.0
#
#    HeadingAccuracy  Volleys  Curve  FKAccuracy  LongPassing  Acceleration  \
# 0             70.0     86.0   93.0        94.0         87.0          91.0
# 1             89.0     87.0   81.0        76.0         77.0          89.0
# 2             62.0     84.0   88.0        87.0         78.0          94.0
# 3             21.0     13.0   21.0        19.0         51.0          57.0
# 4             55.0     82.0   85.0        83.0         91.0          78.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0     91.0       95.0     95.0       85.0     68.0     72.0      59.0
# 1     87.0       96.0     70.0       95.0     95.0     88.0      79.0
# 2     96.0       94.0     84.0       80.0     61.0     81.0      49.0
# 3     60.0       90.0     43.0       31.0     67.0     43.0      64.0
# 4     79.0       91.0     77.0       91.0     63.0     90.0      75.0
#
#    LongShots  Aggression  Positioning  Vision  Penalties  Composure  GKDiving  \
# 0       94.0        48.0         94.0    94.0       75.0       96.0       6.0
# 1       93.0        63.0         95.0    82.0       85.0       95.0       7.0
# 2       82.0        56.0         89.0    87.0       81.0       94.0       9.0
# 3       12.0        38.0         12.0    68.0       40.0       68.0      90.0
# 4       91.0        76.0         87.0    94.0       79.0       88.0      15.0
#
#    Release Clause
# 0     226500000.0
# 1     127100000.0
# 2     228100000.0
# 3     138600000.0
# 4     196400000.0

# %%
categorical_data.head()
# Out:
#   Nationality                 Club Preferred Foot       Work Rate Body Type  \
# 0   Argentina         FC Barcelona           Left  Medium/ Medium    Normal
# 1    Portugal             Juventus          Right       High/ Low    Normal
# 2      Brazil  Paris Saint-Germain          Right    High/ Medium    Normal
# 3       Spain    Manchester United          Right  Medium/ Medium      Lean
# 4     Belgium      Manchester City          Right      High/ High    Normal
#
#   Position
# 0       RF
# 1       ST
# 2       LW
# 3       GK
# 4      RCM

# %%
for col in categorical_data.columns:
    print(col)
    print("----------------------------")
    print(football_df[col].value_counts())
# Out:
# Nationality
# ----------------------------
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
# Brazil                   827
# Italy                    702
# Colombia                 618
# Japan                    478
# Netherlands              453
# Sweden                   397
# China PR                 392
# Chile                    391
# Republic of Ireland      368
# Mexico                   366
# United States            353
# Poland                   350
# Norway                   341
# Saudi Arabia             340
# Denmark                  336
# Korea Republic           335
# Portugal                 322
# Turkey                   303
# Austria                  298
# Scotland                 286
# Belgium                  260
# Australia                236
# Switzerland              220
# Uruguay                  149
# Senegal                  130
# Wales                    129
# Croatia                  126
# Serbia                   126
# Nigeria                  121
# Ghana                    114
# Greece                   102
# Ivory Coast              100
# Czech Republic           100
# Cameroon                  90
# Morocco                   85
# Paraguay                  85
# Northern Ireland          80
# Russia                    79
# Ukraine                   73
# South Africa              71
# Venezuela                 67
# Finland                   67
# Canada                    64
# Bosnia Herzegovina        61
# Algeria                   60
# Slovenia                  55
# Romania                   54
# Slovakia                  54
# DR Congo                  52
# Iceland                   47
# New Zealand               44
# Ecuador                   43
# Mali                      43
# Albania                   40
# Hungary                   38
# Peru                      37
# Kosovo                    33
# Jamaica                   32
# Tunisia                   32
# Bulgaria                  32
# Egypt                     31
# Guinea                    31
# India                     30
# Bolivia                   30
# Costa Rica                30
# Georgia                   26
# Congo                     25
# Montenegro                23
# FYR Macedonia             20
# Cape Verde                19
# Iran                      17
# Burkina Faso              16
# Honduras                  16
# Angola                    15
# Gambia                    15
# Guinea Bissau             15
# Benin                     15
# Gabon                     15
# Panama                    15
# Israel                    14
# Curacao                   14
# Estonia                   13
# Zimbabwe                  13
# Madagascar                12
# Togo                      12
# Armenia                   10
# Kenya                     10
# Haiti                     10
# Syria                      9
# Zambia                     9
# Luxembourg                 8
# Lithuania                  8
# Cyprus                     8
# Iraq                       7
# Comoros                    6
# Faroe Islands              6
# Uganda                     6
# Latvia                     6
# Sierra Leone               6
# Azerbaijan                 5
# El Salvador                5
# Moldova                    5
# Equatorial Guinea          5
# Thailand                   5
# Montserrat                 4
# Trinidad & Tobago          4
# Suriname                   4
# Afghanistan                4
# Belarus                    4
# Kazakhstan                 4
# Libya                      4
# Mozambique                 4
# Antigua & Barbuda          4
# Korea DPR                  4
# Mauritania                 4
# Cuba                       4
# Barbados                   3
# Niger                      3
# Central African Rep.       3
# Guyana                     3
# Namibia                    3
# Tanzania                   3
# St Kitts Nevis             3
# Burundi                    3
# Liechtenstein              3
# Sudan                      3
# Guatemala                  3
# Hong Kong                  2
# Nicaragua                  2
# Eritrea                    2
# Dominican Republic         2
# Chad                       2
# Philippines                2
# Uzbekistan                 2
# Bermuda                    2
# Belize                     1
# Qatar                      1
# Ethiopia                   1
# Fiji                       1
# Grenada                    1
# Andorra                    1
# Kuwait                     1
# Indonesia                  1
# Oman                       1
# Rwanda                     1
# New Caledonia              1
# São Tomé & Príncipe        1
# Malta                      1
# Lebanon                    1
# Mauritius                  1
# Puerto Rico                1
# Jordan                     1
# St Lucia                   1
# South Sudan                1
# Palestine                  1
# Liberia                    1
# Guam                       1
# Botswana                   1
# United Arab Emirates       1
# Name: Nationality, dtype: int64
# Club
# ----------------------------
# No Club                                241
# CD Leganés                              33
# FC Barcelona                            33
# Manchester United                       33
# Everton                                 33
# Burnley                                 33
# Wolverhampton Wanderers                 33
# Real Madrid                             33
# Empoli                                  33
# Fortuna Düsseldorf                      33
# Borussia Dortmund                       33
# Rayo Vallecano                          33
# Frosinone                               33
# TSG 1899 Hoffenheim                     33
# Valencia CF                             33
# Newcastle United                        33
# Manchester City                         33
# Tottenham Hotspur                       33
# RC Celta                                33
# AS Monaco                               33
# Atlético Madrid                         33
# Chelsea                                 33
# Liverpool                               33
# Eintracht Frankfurt                     33
# Arsenal                                 33
# Southampton                             33
# Cardiff City                            33
# Bournemouth                             32
# Lazio                                   32
# VfL Wolfsburg                           32
# FC Nantes                               32
# 1. FSV Mainz 05                         32
# Hertha BSC                              32
# Leicester City                          32
# West Ham United                         32
# Villarreal CF                           32
# Fulham                                  32
# Crystal Palace                          32
# SV Werder Bremen                        32
# Levante UD                              32
# Huddersfield Town                       32
# Brighton & Hove Albion                  32
# Athletic Club de Bilbao                 31
# Real Sociedad                           31
# FC Girondins de Bordeaux                31
# Toulouse Football Club                  31
# FC Augsburg                             31
# Sporting CP                             30
# Club América                            30
# AZ Alkmaar                              30
# Al Hilal                                30
# Nottingham Forest                       30
# Al Ahli                                 30
# Ajax                                    30
# Minnesota United FC                     30
# Cosenza                                 30
# Al Shabab                               30
# Sagan Tosu                              30
# Brescia                                 30
# Millwall                                30
# FC Emmen                                30
# Puebla FC                               30
# Yeni Malatyaspor                        30
# Real Salt Lake                          30
# Yokohama F. Marinos                     30
# Fenerbahçe SK                           30
# Al Hazem                                30
# Júbilo Iwata                            30
# Real Oviedo                             30
# SC Paderborn 07                         30
# Club Necaxa                             30
# Livorno                                 30
# PSV                                     30
# Hamburger SV                            30
# Bristol City                            30
# Gamba Osaka                             30
# Vitória Guimarães                       30
# Leeds United                            30
# AS Nancy Lorraine                       30
# Al Batin                                30
# FC St. Pauli                            30
# ESTAC Troyes                            30
# Gimnàstic de Tarragona                  30
# Kawasaki Frontale                       30
# Ipswich Town                            30
# Tigres U.A.N.L.                         30
# Kashima Antlers                         30
# SC Freiburg                             30
# Derby County                            30
# Sevilla FC                              30
# Portland Timbers                        30
# Al Qadisiyah                            30
# Carpi                                   30
# Padova                                  30
# Cerezo Osaka                            30
# FC Lorient                              30
# Stoke City                              30
# Middlesbrough                           30
# Angers SCO                              30
# West Bromwich Albion                    30
# Shonan Bellmare                         30
# Çaykur Rizespor                         30
# Antalyaspor                             30
# CD Tenerife                             30
# Ascoli                                  30
# Málaga CF                               30
# Reading                                 30
# Udinese                                 30
# Real Valladolid CF                      30
# FC Ingolstadt 04                        30
# V-Varen Nagasaki                        30
# Le Havre AC                             30
# Club León                               30
# Ettifaq FC                              30
# Bursaspor                               30
# Cádiz CF                                30
# Birmingham City                         30
# Sheffield United                        30
# Extremadura UD                          30
# Bolton Wanderers                        30
# CD Lugo                                 30
# Aston Villa                             30
# FC Tokyo                                30
# Vissel Kobe                             30
# Orlando City SC                         30
# Borussia Mönchengladbach                30
# De Graafschap                           30
# Paris Saint-Germain                     30
# Shimizu S-Pulse                         30
# Swansea City                            30
# NAC Breda                               30
# Real Zaragoza                           30
# Al Raed                                 30
# Querétaro                               30
# Norwich City                            30
# Hull City                               30
# Al Wehda                                30
# Queens Park Rangers                     30
# SD Huesca                               30
# Alanyaspor                              30
# Al Ittihad                              30
# Albacete BP                             30
# Houston Dynamo                          30
# Brentford                               30
# Real Sporting de Gijón                  30
# Palermo                                 30
# UD Almería                              30
# Deportivo de La Coruña                  30
# Al Faisaly                              30
# Blackburn Rovers                        30
# Wigan Athletic                          30
# Racing Club de Lens                     30
# Galatasaray SK                          30
# Sheffield Wednesday                     30
# Watford                                 29
# Atlanta United                          29
# Cittadella                              29
# Stade de Reims                          29
#  SSV Jahn Regensburg                    29
# Olympique de Marseille                  29
# Valenciennes FC                         29
# Pachuca                                 29
# FC Dallas                               29
# 1. FC Nürnberg                          29
# Holstein Kiel                           29
# Club Atlas                              29
# Amiens SC                               29
# Philadelphia Union                      29
# SV Sandhausen                           29
# Granada CF                              29
# Parma                                   29
# Olympique Lyonnais                      29
# Heracles Almelo                         29
# RCD Espanyol                            29
# SD Eibar                                29
# Hannover 96                             29
# Al Taawoun                              29
# Montreal Impact                         29
# Guadalajara                             29
# Al Nassr                                29
# AD Alcorcón                             29
# UD Las Palmas                           29
# Hellas Verona                           29
# Girona FC                               29
# MKE Ankaragücü                          29
# FC Erzgebirge Aue                       29
# Hokkaido Consadole Sapporo              29
# FC Schalke 04                           29
# New York Red Bulls                      29
# U.N.A.M.                                29
# Tiburones Rojos de Veracruz             29
# FC Bayern München                       29
# Lecce                                   29
# Preston North End                       29
# Livingston FC                           28
# Northampton Town                        28
# Orlando Pirates                         28
# Newell's Old Boys                       28
# Medipol Başakşehir FK                   28
# Jaguares de Córdoba                     28
# Notts County                            28
# DSC Arminia Bielefeld                   28
# Lokomotiv Moscow                        28
# US Salernitana 1919                     28
# Deportes Tolima                         28
# Fleetwood Town                          28
# KV Kortrijk                             28
# Tranmere Rovers                         28
# Atlético Huila                          28
# Montpellier HSC                         28
# Deportivo Cali                          28
# Racing Club                             28
# Club Atlético Huracán                   28
# CD O'Higgins                            28
# Patronato                               28
# Deportivo Toluca                        28
# Club Brugge KV                          28
# KSV Cercle Brugge                       28
# Toronto FC                              28
# Plymouth Argyle                         28
# Argentinos Juniors                      28
# Getafe CF                               28
# SL Benfica                              28
# Eintracht Braunschweig                  28
# Jeonnam Dragons                         28
# Sint-Truidense VV                       28
# Bradford City                           28
# San Martin de Tucumán                   28
# Godoy Cruz                              28
# FC Seoul                                28
# FC Sochaux-Montbéliard                  28
# FC Porto                                28
# Chongqing Dangdai Lifan FC SWM Team     28
# DC United                               28
# Beşiktaş JK                             28
# Shanghai Greenland Shenhua FC           28
# Sangju Sangmu FC                        28
# SV Meppen                               28
# Tianjin TEDA FC                         28
# Itagüí Leones FC                        28
# Jeonbuk Hyundai Motors                  28
# 1. FC Union Berlin                      28
# TSV 1860 München                        28
# Club Atlético Lanús                     28
# Shanghai SIPG FC                        28
# San Lorenzo de Almagro                  28
# Dinamo Zagreb                           28
# Colo-Colo                               28
# Defensa y Justicia                      28
# 1. FC Köln                              28
# Standard de Liège                       28
# Cambridge United                        28
# América de Cali                         28
# Bristol Rovers                          28
# Stade Malherbe Caen                     28
# Dynamo Kyiv                             28
# Rangers FC                              28
# Panathinaikos FC                        28
# Shakhtar Donetsk                        28
# Yeovil Town                             28
# Gangwon FC                              28
# Changchun Yatai FC                      28
# Motherwell                              28
# CD Aves                                 28
# Beijing Sinobo Guoan FC                 28
# Rosario Central                         28
# RB Leipzig                              28
# Atlético Tucumán                        28
# Guangzhou Evergrande Taobao FC          28
# Ulsan Hyundai FC                        28
# Sporting de Charleroi                   28
# CD Palestino                            28
# Blackpool                               28
# Hebei China Fortune FC                  28
# OGC Nice                                28
# Sporting Lokeren                        28
# Club Atlético Talleres                  28
# CD Numancia                             28
# AEK Athens                              28
# Al Fayha                                28
# Junior FC                               28
# Unión Española                          28
# Royal Excel Mouscron                    28
# Mansfield Town                          28
# Suwon Samsung Bluewings                 28
# Rio Ave FC                              28
# SG Dynamo Dresden                       28
# Southend United                         28
# Waasland-Beveren                        28
# Curicó Unido                            28
# Exeter City                             28
# Bury                                    28
# Jeju United FC                          28
# Göztepe SK                              28
# Guangzhou R&F; FC                       28
# Kashiwa Reysol                          28
# Atlético Bucaramanga                    28
# Millonarios FC                          28
# Doncaster Rovers                        28
# Vélez Sarsfield                         28
# Coventry City                           28
# Spezia                                  28
# Vitória de Setúbal                      28
# Olympiacos CFP                          28
# Stevenage                               28
# KFC Uerdingen 05                        28
# Oxford United                           28
# Gillingham                              28
# Feyenoord                               28
# CF Reus Deportiu                        28
# Rionegro Águilas                        28
# RSC Anderlecht                          28
# VfL Sportfreunde Lotte                  28
# Al Fateh                                28
# Portsmouth                              28
# CD Antofagasta                          28
# Deportes Iquique                        28
# Club Atlético Aldosivi                  28
# RCD Mallorca                            28
# Boyacá Chicó FC                         28
# Independiente                           28
# Daegu FC                                28
# RC Strasbourg Alsace                    28
# Patriotas Boyacá FC                     28
# Club Deportes Temuco                    28
# Once Caldas                             28
# Club Atlético Tigre                     28
# Envigado FC                             28
# Henan Jianye FC                         28
# SpVgg Greuther Fürth                    28
# Sparta Praha                            28
# Universidad Católica                    28
# Colchester United                       28
# Unión de Santa Fe                       28
# Charlton Athletic                       28
# Independiente Santa Fe                  28
# Vitesse                                 28
# Atlético Nacional                       28
# Kilmarnock                              28
# Deportivo Pasto                         28
# Chamois Niortais Football Club          28
# Milton Keynes Dons                      28
# Club Atlético Colón                     28
# San Luis de Quillota                    28
# 1. FC Heidenheim 1846                   28
# Club Tijuana                            28
# Independiente Medellín                  28
# Beijing Renhe FC                        28
# PFC CSKA Moscow                         28
# SC Braga                                28
# ADO Den Haag                            28
# Celtic                                  28
# Bologna                                 28
# Pescara                                 28
# Rochdale                                28
# Venezia FC                              28
# Morecambe                               28
# Jiangsu Suning FC                       28
# KAS Eupen                               28
# Gimnasia y Esgrima La Plata             28
# Incheon United FC                       28
# Willem II                               28
# Chievo Verona                           28
# Red Star FC                             28
# Estudiantes de La Plata                 28
# Burton Albion                           28
# FC Energie Cottbus                      28
# FC Carl Zeiss Jena                      28
# La Equidad                              28
# Karlsruher SC                           28
# Alianza Petrolera                       28
# Barnsley                                28
# Universidad de Chile                    28
# Gyeongnam FC                            28
# Guizhou Hengfeng FC                     28
# Crewe Alexandra                         28
# Dalian YiFang FC                        28
# SK Slavia Praha                         28
# Lincoln City                            28
# Hamilton Academical FC                  28
# KAA Gent                                28
# Trabzonspor                             28
# San Martín de San Juan                  28
# Monarcas Morelia                        28
# Audax Italiano                          28
# Accrington Stanley                      28
# Sunderland                              28
# Aberdeen                                27
# Shrewsbury                              27
# Unión La Calera                         27
# Hammarby IF                             27
# Odense Boldklub                         27
# FC Wacker Innsbruck                     27
# FC Nordsjælland                         27
# FC Midtjylland                          27
# Milan                                   27
# Jagiellonia Białystok                   27
# IF Elfsborg                             27
# CD Universidad de Concepción            27
# Dundee FC                               27
# Seattle Sounders FC                     27
# St. Mirren                              27
# Neuchâtel Xamax                         27
# AIK                                     27
# SønderjyskE                             27
# Trelleborgs FF                          27
# New England Revolution                  27
# Aarhus GF                               27
# FC Admira Wacker Mödling                27
# Real Betis                              27
# Korona Kielce                           27
# Stabæk Fotball                          27
# Sampdoria                               27
# Cracovia                                27
# Grasshopper Club Zürich                 27
# Lobos BUAP                              27
# Aalborg BK                              27
# St. Johnstone FC                        27
# Zagłębie Lubin                          27
# Legia Warszawa                          27
# Vancouver Whitecaps FC                  27
# CD Huachipato                           27
# Atiker Konyaspor                        27
# Sporting Kansas City                    27
# Kalmar FF                               27
# SKN St. Pölten                          27
# Örebro SK                               27
# FC Würzburger Kickers                   27
# Brøndby IF                              27
# Vegalta Sendai                          27
# Arka Gdynia                             27
# FC Luzern                               27
# Boavista FC                             27
# SK Rapid Wien                           27
# IK Sirius                               27
# Urawa Red Diamonds                      27
# Lechia Gdańsk                           27
# Heart of Midlothian                     27
# Sassuolo                                27
# Portimonense SC                         27
# FK Bodø/Glimt                           27
# SPAL                                    27
# Piast Gliwice                           27
# SV Darmstadt 98                         27
# SC Heerenveen                           27
# FC Zürich                               27
# Miedź Legnica                           27
# FC Lugano                               27
# Górnik Zabrze                           27
# FC Basel 1893                           27
# SV Mattersburg                          27
# Spartak Moscow                          27
# Genoa                                   27
# CD Everton de Viña del Mar              27
# VfB Stuttgart                           27
# BK Häcken                               27
# Walsall                                 27
# PEC Zwolle                              27
# AJ Auxerre                              27
# Shandong Luneng TaiShan FC              27
# FC Red Bull Salzburg                    27
# FC Sion                                 27
# Club Atlético Banfield                  27
# Stade Rennais FC                        27
# Foggia                                  27
# Vendsyssel FF                           27
# Belgrano de Córdoba                     27
# Sivasspor                               27
# Malmö FF                                27
# Fortuna Sittard                         27
# FK Austria Wien                         27
# Vejle Boldklub                          27
# Kaizer Chiefs                           27
# PAOK                                    27
# Lech Poznań                             27
# SK Brann                                27
# Boca Juniors                            27
# Scunthorpe United                       27
# Deportivo Alavés                        27
# Pohang Steelers                         27
# SC Preußen Münster                      27
# Nagoya Grampus                          27
# Nîmes Olympique                         27
# Newport County                          26
# Roma                                    26
# VfL Bochum 1848                         26
# VfL Osnabrück                           26
# AFC Wimbledon                           26
# CD Feirense                             26
# TSV Hartberg                            26
# Wisła Płock                             26
# Monterrey                               26
# SV Zulte-Waregem                        26
# Columbus Crew SC                        26
# SCR Altach                              26
# FC Metz                                 26
# Molde FK                                26
# IF Brommapojkarna                       26
# Perugia                                 26
# Vålerenga Fotball                       26
# FC Utrecht                              26
# Sanfrecce Hiroshima                     26
# SC Fortuna Köln                         26
# Swindon Town                            26
# Peterborough United                     26
# MSV Duisburg                            26
# SpVgg Unterhaching                      26
# San Jose Earthquakes                    26
# CD Nacional                             26
# Tianjin Quanjian FC                     26
# 1. FC Magdeburg                         26
# Rosenborg BK                            26
# Santos Laguna                           26
# FC Groningen                            26
# Wolfsberger AC                          26
# Excelsior                               26
# VVV-Venlo                               26
# KV Oostende                             26
# 1. FC Kaiserslautern                    26
# Pogoń Szczecin                          26
# AS Béziers                              26
# Sarpsborg 08 FF                         26
# Torino                                  26
# Elche CF                                26
# Santa Clara                             26
# New York City FC                        26
# Córdoba CF                              26
# Dijon FCO                               26
# Bayer 04 Leverkusen                     26
# Macclesfield Town                       26
# Port Vale                               26
# Rotherham United                        26
# CF Rayo Majadahonda                     26
# Grenoble Foot 38                        26
# Wisła Kraków                            26
# FC Thun                                 26
# HJK Helsinki                            26
# Akhisar Belediyespor                    26
# AC Horsens                              25
# Stade Brestois 29                       25
# Esbjerg fB                              25
# Ohod Club                               25
# LOSC Lille                              25
# BB Erzurumspor                          25
# Hallescher FC                           25
# CA Osasuna                              25
# Hibernian                               25
# Luton Town                              25
# Grimsby Town                            25
# Adelaide United                         25
# Wycombe Wanderers                       25
# Sydney FC                               25
# Clermont Foot 63                        25
# Bohemian FC                             25
# Moreirense FC                           25
# Śląsk Wrocław                           25
# US Orléans Loiret Football              25
# En Avant de Guingamp                    25
# Los Angeles FC                          25
# Carlisle United                         25
# FC St. Gallen                           25
# Napoli                                  25
# US Cremonese                            25
# Zagłębie Sosnowiec                      25
# Central Coast Mariners                  25
# Cruz Azul                               25
# Kayserispor                             25
# Royal Antwerp FC                        25
# LA Galaxy                               25
# SK Sturm Graz                           25
# Benevento                               25
# FC Hansa Rostock                        25
# Paris FC                                25
# Perth Glory                             25
# Cork City                               25
# River Plate                             25
# Waterford FC                            25
# Djurgårdens IF                          25
# CD Tondela                              25
# Juventus                                25
# FSV Zwickau                             25
# Hobro IK                                25
# Randers FC                              25
# Melbourne City FC                       25
# KRC Genk                                25
# Oldham Athletic                         25
# Western Sydney Wanderers                25
# GD Chaves                               25
# VfR Aalen                               24
# SG Sonnenhof Großaspach                 24
# Kristiansund BK                         24
# Crawley Town                            24
# Inter                                   24
# Forest Green Rovers                     24
# Newcastle Jets                          24
# Crotone                                 24
# Atalanta                                24
# Os Belenenses                           24
# LASK Linz                               24
# AS Saint-Étienne                        24
# Cheltenham Town                         24
# Cagliari                                24
# BSC Young Boys                          24
# SV Wehen Wiesbaden                      24
# Lillestrøm SK                           24
# Ranheim Fotball                         24
# IK Start                                24
# Sandefjord Fotball                      24
# Viktoria Plzeň                          24
# Strømsgodset IF                         24
# IFK Norrköping                          24
# La Berrichonne de Châteauroux           24
# Fiorentina                              24
# Clube Sport Marítimo                    23
# GFC Ajaccio                             23
# Kasimpaşa SK                            23
# AC Ajaccio                              23
# FC København                            23
# Chicago Fire                            23
# St. Patrick's Athletic                  23
# Dundalk                                 23
# Odds BK                                 23
# Brisbane Roar                           23
# IFK Göteborg                            23
# GIF Sundsvall                           23
# Colorado Rapids                         23
# Bray Wanderers                          23
# FK Haugesund                            22
# Östersunds FK                           22
# Shamrock Rovers                         22
# Dalkurd FF                              21
# Wellington Phoenix                      21
# Melbourne Victory                       21
# Botafogo                                20
# América FC (Minas Gerais)               20
# Tromsø IL                               20
# Grêmio                                  20
# Sport Club do Recife                    20
# Fluminense                              20
# Cruzeiro                                20
# Chapecoense                             20
# Atlético Paranaense                     20
# Paraná                                  20
# Santos                                  20
# Bahia                                   20
# Internacional                           20
# Atlético Mineiro                        20
# Vitória                                 20
# Ceará Sporting Club                     20
# Limerick FC                             19
# Sligo Rovers                            19
# Derry City                              18
# Name: Club, dtype: int64
# Preferred Foot
# ----------------------------
# Right    13996
# Left      4211
# Name: Preferred Foot, dtype: int64
# Work Rate
# ----------------------------
# Medium/ Medium    9858
# High/ Medium      3173
# Medium/ High      1690
# High/ High        1015
# Medium/ Low        850
# High/ Low          699
# Low/ Medium        449
# Low/ High          439
# Low/ Low            34
# Name: Work Rate, dtype: int64
# Body Type
# ----------------------------
# Normal    10650
# Lean       6417
# Stocky     1140
# Name: Body Type, dtype: int64
# Position
# ----------------------------
# ST     2212
# GK     2025
# CB     1778
# CM     1394
# LB     1322
# RB     1291
# RM     1124
# LM     1095
# CAM     958
# CDM     948
# RCB     662
# LCB     648
# LCM     395
# RCM     391
# LW      381
# RW      370
# RDM     248
# LDM     243
# LS      207
# RS      203
# RWB      87
# LWB      78
# CF       74
# RAM      21
# LAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %% [markdown]
# **1. Data visualisation**

# %% [markdown]
# **Plot histograms of count of players on the basis of some attributes like height.**

# %%
def snsplotting_height(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xlabel(xlabel = f'{name} in Foot per inch', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

    plt.show()

snsplotting_height('Height')

# %%
def snsplotting_weight(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    ax.set_xlabel(xlabel = f'{name} in lbs', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50),rotation=90)


    plt.show()

snsplotting_weight('Weight')

# %%
def snsplotting_bodyType(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xlabel(xlabel = f'{name} of the Players', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    plt.show()

snsplotting_bodyType('Body Type')

# %%
def snsplotting_age(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xlabel(xlabel = f'{name} of the Players', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    
    plt.show()

snsplotting_age('Age')

# %%
# Plotting the Nationality of the Players

def snsplotting_Nationality(name): 
    plt.figure(figsize = (50, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xlabel(xlabel = f'{name} of the Players', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    
    plt.show()

snsplotting_Nationality('Nationality')

# %%
def snsplotting_joined(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name} year', fontsize = 20)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    ax.set_xlabel(xlabel = f'{name} of the Players joined', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    plt.show()

snsplotting_joined('Joined')

# %%
def snsplotting_Contract_Valid_Until(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name} year', fontsize = 20)
    # ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
    ax.set_xlabel(xlabel = f'{name} of the Players', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    plt.show()

snsplotting_Contract_Valid_Until('Contract Valid Until')

# %%
# Prefered foot of the players

def snsplotting_Contract_Valid_Until(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xlabel(xlabel = f'{name} of the Players', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)

    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    plt.show()

snsplotting_Contract_Valid_Until('Preferred Foot')

# %%
# Position of the players

def snsplotting_Contract_Valid_Until(name): 
    plt.figure(figsize = (13, 8))
    ax = sns.countplot(x = name,data = Actual_football_df, palette = 'dark')
    ax.set_title(label = f'Count of players on Basis of {name}', fontsize = 20)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    ax.set_xlabel(xlabel = f'{name} of the Players', fontsize = 16)
    ax.set_ylabel(ylabel = 'Count', fontsize = 16)
    for p in ax.patches:
       ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
    plt.show()

snsplotting_Contract_Valid_Until('Position')

# %% [markdown]
# **Distribution of players in different clubs/country on the basis of some attribute**

# %%
# Getting the Country wide list of players

def nationality(x):
    return Actual_football_df[Actual_football_df['Nationality'] == x][['Name','Overall','Potential','Position']]


# Apply for Loop for all the countries.

nationality('India')
# Out:
#                   Name  Overall  Potential Position
# 8605        S. Chhetri       67         67       LS
# 10011       S. Jhingan       65         71      RCB
# 12598    J. Lalpekhlua       63         64       RS
# 12811  G. Singh Sandhu       63         68       GK
# 13508    A. Edathodika       62         62      LCB
# 14054        P. Halder       61         67      RCM
# 14199         P. Kotal       61         66       RB
# 14218         L. Ralte       61         62       LW
# 14705           N. Das       60         65       LB
# 14786         U. Singh       60         67       RM
# 14915       H. Narzary       60         66       LM
# 15356         R. Singh       59         59       ST
# 15643         S. Singh       59         65       CB
# 15652         A. Thapa       59         71      LCM
# 15855       M. Rafique       58         61       CM
# 15864         A. Singh       58         62       GK
# 15884         B. Singh       58         58       ST
# 16135          S. Bose       58         66       LB
# 16265        R. Borges       58         60      CDM
# 16450          S. Paul       57         57       ST
# 16499        A. Mondal       57         57       CB
# 16539  L. Lalruatthara       57         63       ST
# 16793       E. Lyngdoh       56         56       ST
# 16903   J. Lalrinzuala       56         64       LB
# 16976     A. Kuruniyan       56         70       LW
# 17129         J. Singh       55         58       ST
# 17197         V. Kaith       55         64       GK
# 17339         S. Passi       54         63       ST
# 17436   D. Lalhlimpuia       54         67       ST
# 17539         C. Singh       53         62       ST

# %%
Actual_football_df.shape
# Out:
# (18207, 89)

# %%
football_df.shape
# Out:
# (18207, 45)

# %% [markdown]
# **Features of players according to their position.**

# %%
plt.figure(figsize=(6, 14))
heatmap = sns.heatmap(Actual_football_df.corr()[['Positioning']].sort_values(by='Positioning', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Sales Price', fontdict={'fontsize':15}, pad=16);

# %%
## We are considering the feature that are having the corelation between 0.5 to 0.8

feature_list = ['Balance', 'Stamina', 'CM', 'Agility', 'Vision', 'Crossing']

# %% [markdown]
# **Can you use visualisation techniques to find outliers**

# %%
# Scatter plot for finding the outliers of the players

fig, ax = plt.subplots(figsize = (100,10))
ax.scatter(Actual_football_df['Value'], Actual_football_df['Wage'])
 
# x-axis label
ax.set_xlabel('Skills of the players')
 
# y-axis label
ax.set_ylabel('Wage in €')
plt.show()

# %%
numeric_data.head()
# Out:
#    Unnamed: 0  Age  Potential        Value      Wage  Special  \
# 0           0   31         94  110500000.0  565000.0     2202
# 1           1   33         94   77000000.0  405000.0     2228
# 2           2   26         93  118500000.0  290000.0     2143
# 3           3   27         93   72000000.0  260000.0     1471
# 4           4   27         92  102000000.0  355000.0     2281
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  Joined  \
# 0                       5.0        4.0          4.0           10.0  2004.0
# 1                       5.0        4.0          5.0            7.0  2018.0
# 2                       5.0        5.0          5.0           10.0  2017.0
# 3                       4.0        3.0          1.0            1.0  2011.0
# 4                       4.0        5.0          4.0            7.0  2015.0
#
#    Contract Valid Until  Height  Weight    LS   LWB  Crossing  Finishing  \
# 0                2021.0    5.70   159.0  88.0  64.0      84.0       95.0
# 1                2022.0    6.20   183.0  91.0  65.0      84.0       94.0
# 2                2022.0    5.90   150.0  84.0  65.0      79.0       87.0
# 3                2020.0    6.40   168.0   0.0   0.0      17.0       13.0
# 4                2023.0    5.11   154.0  82.0  77.0      93.0       82.0
#
#    HeadingAccuracy  Volleys  Curve  FKAccuracy  LongPassing  Acceleration  \
# 0             70.0     86.0   93.0        94.0         87.0          91.0
# 1             89.0     87.0   81.0        76.0         77.0          89.0
# 2             62.0     84.0   88.0        87.0         78.0          94.0
# 3             21.0     13.0   21.0        19.0         51.0          57.0
# 4             55.0     82.0   85.0        83.0         91.0          78.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0     91.0       95.0     95.0       85.0     68.0     72.0      59.0
# 1     87.0       96.0     70.0       95.0     95.0     88.0      79.0
# 2     96.0       94.0     84.0       80.0     61.0     81.0      49.0
# 3     60.0       90.0     43.0       31.0     67.0     43.0      64.0
# 4     79.0       91.0     77.0       91.0     63.0     90.0      75.0
#
#    LongShots  Aggression  Positioning  Vision  Penalties  Composure  GKDiving  \
# 0       94.0        48.0         94.0    94.0       75.0       96.0       6.0
# 1       93.0        63.0         95.0    82.0       85.0       95.0       7.0
# 2       82.0        56.0         89.0    87.0       81.0       94.0       9.0
# 3       12.0        38.0         12.0    68.0       40.0       68.0      90.0
# 4       91.0        76.0         87.0    94.0       79.0       88.0      15.0
#
#    Release Clause
# 0     226500000.0
# 1     127100000.0
# 2     228100000.0
# 3     138600000.0
# 4     196400000.0

# %% [markdown]
# **3. Hierarchical Clustering**

# %% [markdown]
# **1. Cluster the data using any Agglomerative(bottom-up strategy) method of your choice.**

# %%
#Finding the optimal number of clusters using the dendrogram  
import scipy.cluster.hierarchy as shc  

dendro = shc.dendrogram(shc.linkage(numeric_data, method="ward"))  
# plt.figure(figsize = (13, 8))
plt.title("Dendrogrma Plot")  
plt.ylabel("Euclidean Distances")  
plt.xlabel("Number of Players")  
plt.show()

# %%
#training the hierarchical model on dataset  
from sklearn.cluster import AgglomerativeClustering  
hc= AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')  
y_pred= hc.fit_predict(numeric_data)

# %%
#visulaizing the clusters  
plt.scatter(numeric_data['Age'], numeric_data['Curve'], s = 100, c = 'blue', label = 'Cluster 2')  
plt.scatter(numeric_data['Vision'], numeric_data['Balance'], s = 100, c = 'green', label = 'Cluster 3')  
# plt.scatter(numeric_data[y_pred== 2, 0], numeric_data[y_pred == 2, 1], s = 100, c = 'red', label = 'Cluster 3')  
# plt.scatter(numeric_data[y_pred == 3, 0], numeric_data[y_pred == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')  
# plt.scatter(numeric_data[y_pred == 4, 0], numeric_data[y_pred == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')  
plt.title('Clusters of customers')  
plt.xlabel('Annual Income (k$)')  
plt.ylabel('Spending Score (1-100)')  
plt.legend()  
plt.show()

# %% [markdown]
# 4. DBSCAN Algorithm

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets.samples_generator import make_blobs
db = DBSCAN(eps=0.3, metric='euclidean', algorithm='auto')  
y_pred= db.fit_predict(numeric_data)
# X, y = make_blobs(n_samples=1000, centers=4, cluster_std=0.60, random_state=0)
colors = ['royalblue', 'maroon', 'forestgreen', 'mediumorchid', 'tan', 'deeppink', 'olive', 'goldenrod', 'lightcyan', 'navy']
# vectorizer = np.vectorize(lambda x: colors[x % len(colors)])


plt.scatter(X[:,0], X[:,1]) 

# plt.scatter(numeric_data['Age'], numeric_data['Curve'], s = 100, c = 'blue', label = 'Cluster 2')

# %%
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(numeric_data)
distances, indices = nbrs.kneighbors(numeric_data)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)


# The optimal value for epsilon will be found at the point of maximum curvature.
